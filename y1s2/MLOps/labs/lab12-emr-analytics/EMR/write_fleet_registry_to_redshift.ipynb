# %%
jdbc_url = "st126112-redshift-26032026.cziacma7fpyn.us-east-1.redshift.amazonaws.com:5439/dev"
table_name = "fleet_registry"
user = "awsuser"
password = "Awsuser123"

# %%
df.write \
  .format("jdbc") \
  .option("url", jdbc_url) \
  .option("dbtable", table_name) \
  .option("user", user) \
  .option("password", password) \
  .option("driver", "com.amazon.redshift.jdbc.Driver") \
  .mode("append") \
  .save()
